# %% [markdown]
# ### Import Necessary Libraries

# %%
import numpy as np
import pandas as pd

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from sklearn.tree import export_graphviz
import graphviz

# %% [markdown]
# ### Read the CSV file and remove some columns

# %% [markdown]
# ### ROC Curve

# %% [markdown]
# ### Precision-Recall Curve

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

def plot_precision_recall_curve(y_test, y_pred_proba, figsize=(4, 3)):
    precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba)
    avg_precision = average_precision_score(y_test, y_pred_proba)

    plt.figure(figsize=figsize)
    plt.plot(recall, precision, label=f'Avg. Precision = {avg_precision:.2f}')
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title("Precision-Recall Curve")
    plt.legend()
    plt.show()

plot_precision_recall_curve(y_test, y_pred_proba)

# %% [markdown]
# ### Predict New Data

# %%
df_new = pd.read_csv("recent-data.csv")
df_new.drop(['Date', 'Data Quality', 'snow', 'snowdepth', 'stations'], axis=1, inplace=True)

# %%
# Convert 'Day of Week' to numerical representation
df_new['Day of Week'] = df_new['Day of Week'].map(day_mapping)
df_new['conditions'] = le_.fit_transform(df_new['conditions'])
df_new['description'] = le_.fit_transform(df_new['description'])
df_new['icon'] = le_.fit_transform(df_new['icon'])

# Convert following columns to numerical representation
df_new['preciptype'] = df_new['preciptype'].replace({'rain': 1, np.nan: 0})
df_new['Is Remote Synchronous'] = df_new['Is Remote Synchronous'].astype(int)

# Convert timestamp to numerical representation (seconds since midnight)
df_new['sunrise'] = pd.to_datetime(df_new['sunrise'], format='%Y-%m-%dT%H:%M:%S').dt.hour * 3600 + pd.to_datetime(df_new['sunrise'], format='%Y-%m-%dT%H:%M:%S').dt.minute * 60 + pd.to_datetime(df_new['sunrise'], format='%Y-%m-%dT%H:%M:%S').dt.second
df_new['sunset'] = pd.to_datetime(df_new['sunset'], format='%Y-%m-%dT%H:%M:%S').dt.hour * 3600 + pd.to_datetime(df_new['sunset'], format='%Y-%m-%dT%H:%M:%S').dt.minute * 60 + pd.to_datetime(df_new['sunset'], format='%Y-%m-%dT%H:%M:%S').dt.second
# Out:
# /var/folders/zz/typs1gbx6kn17jrqf0x4ny9r0000gn/T/ipykernel_3076/928670445.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_new['preciptype'] = df_new['preciptype'].replace({'rain': 1, np.nan: 0})

# %%
X_new = df_new.drop('Is Class', axis=1)
y_new = df_new['Is Class']

# %%
pred_new = clf.predict(X_new)

# %%
import pandas as pd
from datetime import date, timedelta

# Create the date range from May 18 to May 22, 2024
start_date = date(2024, 5, 18)
end_date = date(2024, 5, 22)
date_range = pd.date_range(start_date, end_date)

# Create the DataFrame
df = pd.DataFrame({'Date': date_range, 'Result': pred_new})

df
# Out:
#         Date  Result
# 0 2024-05-18   False
# 1 2024-05-19   False
# 2 2024-05-20   False
# 3 2024-05-21   False
# 4 2024-05-22   False
